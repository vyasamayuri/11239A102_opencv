# %% [markdown]
# <a href="https://colab.research.google.com/github/vyasamayuri/11239A102_opencv/blob/main/exp8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Out:
#      <input type="file" id="files-9b4c0b19-50a4-42e5-970b-4ae36c0f67d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b4c0b19-50a4-42e5-970b-4ae36c0f67d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for name in uploaded.keys():
    img = cv2.imread(name)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    print(name)
    cv2_imshow(binary)
# Out:
# rotated_by_15_Screen Shot 2018-06-07 at 2.42.37 PM.png
# <PIL.Image.Image image mode=L size=380x404>
# rotated_by_15_Screen Shot 2018-06-07 at 2.41.23 PM.png
# <PIL.Image.Image image mode=L size=396x400>
# rotated_by_15_Screen Shot 2018-06-07 at 2.38.28 PM.png
# <PIL.Image.Image image mode=L size=200x208>
# rotated_by_15_Screen Shot 2018-06-07 at 2.38.04 PM.png
# <PIL.Image.Image image mode=L size=588x440>
# rotated_by_15_Screen Shot 2018-06-07 at 2.37.32 PM.png
# <PIL.Image.Image image mode=L size=386x386>
# rotated_by_15_Screen Shot 2018-06-07 at 2.37.11 PM.png
# <PIL.Image.Image image mode=L size=464x396>
# rotated_by_15_Screen Shot 2018-06-07 at 2.35.10 PM.png
# <PIL.Image.Image image mode=L size=362x318>
# rotated_by_15_Screen Shot 2018-06-07 at 2.25.16 PM.png
# <PIL.Image.Image image mode=L size=258x252>
# rotated_by_15_Screen Shot 2018-06-07 at 2.24.47 PM.png
# <PIL.Image.Image image mode=L size=334x300>
# rotated_by_15_Screen Shot 2018-06-07 at 2.23.40 PM.png
# ...

# %%
 kernel = np.ones((5,5), np.uint8)

for name in uploaded.keys():
    img = cv2.imread(name)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    erosion = cv2.erode(binary, kernel, 1)
    cv2_imshow(erosion)
# Out:
# <PIL.Image.Image image mode=L size=380x404>
# <PIL.Image.Image image mode=L size=396x400>
# <PIL.Image.Image image mode=L size=200x208>
# <PIL.Image.Image image mode=L size=588x440>
# <PIL.Image.Image image mode=L size=386x386>
# <PIL.Image.Image image mode=L size=464x396>
# <PIL.Image.Image image mode=L size=362x318>
# <PIL.Image.Image image mode=L size=258x252>
# <PIL.Image.Image image mode=L size=334x300>
# <PIL.Image.Image image mode=L size=320x318>

# %%
for name in uploaded.keys():
    img = cv2.imread(name)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    dilation = cv2.dilate(binary, kernel, 1)
    cv2_imshow(dilation)
# Out:
# <PIL.Image.Image image mode=L size=380x404>
# <PIL.Image.Image image mode=L size=396x400>
# <PIL.Image.Image image mode=L size=200x208>
# <PIL.Image.Image image mode=L size=588x440>
# <PIL.Image.Image image mode=L size=386x386>
# <PIL.Image.Image image mode=L size=464x396>
# <PIL.Image.Image image mode=L size=362x318>
# <PIL.Image.Image image mode=L size=258x252>
# <PIL.Image.Image image mode=L size=334x300>
# <PIL.Image.Image image mode=L size=320x318>

# %%
for name in uploaded.keys():
    img = cv2.imread(name)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)
    cv2_imshow(opening)
# Out:
# <PIL.Image.Image image mode=L size=380x404>
# <PIL.Image.Image image mode=L size=396x400>
# <PIL.Image.Image image mode=L size=200x208>
# <PIL.Image.Image image mode=L size=588x440>
# <PIL.Image.Image image mode=L size=386x386>
# <PIL.Image.Image image mode=L size=464x396>
# <PIL.Image.Image image mode=L size=362x318>
# <PIL.Image.Image image mode=L size=258x252>
# <PIL.Image.Image image mode=L size=334x300>
# <PIL.Image.Image image mode=L size=320x318>

# %%
for name in uploaded.keys():
    img = cv2.imread(name)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    closing = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
    cv2_imshow(closing)
# Out:
# <PIL.Image.Image image mode=L size=380x404>
# <PIL.Image.Image image mode=L size=396x400>
# <PIL.Image.Image image mode=L size=200x208>
# <PIL.Image.Image image mode=L size=588x440>
# <PIL.Image.Image image mode=L size=386x386>
# <PIL.Image.Image image mode=L size=464x396>
# <PIL.Image.Image image mode=L size=362x318>
# <PIL.Image.Image image mode=L size=258x252>
# <PIL.Image.Image image mode=L size=334x300>
# <PIL.Image.Image image mode=L size=320x318>

# %%
for name in uploaded.keys():
    img = cv2.imread(name)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    gradient = cv2.morphologyEx(binary, cv2.MORPH_GRADIENT, kernel)
    cv2_imshow(gradient)
# Out:
# <PIL.Image.Image image mode=L size=380x404>
# <PIL.Image.Image image mode=L size=396x400>
# <PIL.Image.Image image mode=L size=200x208>
# <PIL.Image.Image image mode=L size=588x440>
# <PIL.Image.Image image mode=L size=386x386>
# <PIL.Image.Image image mode=L size=464x396>
# <PIL.Image.Image image mode=L size=362x318>
# <PIL.Image.Image image mode=L size=258x252>
# <PIL.Image.Image image mode=L size=334x300>
# <PIL.Image.Image image mode=L size=320x318>
